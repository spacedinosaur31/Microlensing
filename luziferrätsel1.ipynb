# %%
from pickle import FALSE


prim = []
for i in range(2, 99):
    x = False
    for z in range(2, i-1): 
        if i % z == 0:
            x = True
    if x is False:
        prim.append(i)  
            
falsesums = []
for x in range(2, 99):
    for y in range(2, 99):
        Sum = x + y
        count = 0
        s = False
        if x in prim:
            if y in prim:
                falsesums.append(Sum)
                
sums = []      
for i in range (4, 198):
    if i not in falsesums:
            sums.append(i)
 

for i in sums:
    #if i < 20:
        for x in range(2, i):
            for y in range(2, i):
                if y != x**2:
                    if x != y**2:
                        sum = x + y
                        if sum == i:
                            prod = x*y
                            count = []
                            for s in range(2, prod):
                                for q in range(2, prod):
                                    sum = s + q
                                    if sum in sums:
                                        count.append(1)
                                    if count.count(1) == 2:
                                        print(x,y)
# Out:
# 2 9
# 2 9
# 2 9
# 2 9
# 2 9
# 2 9
# 2 9
# 2 9
# 2 9
# 3 8
# 3 8
# 3 8
# 3 8
# 3 8
# 3 8
# 4 7
# 4 7
# 4 7
# 4 7
# 4 7
# 4 7
# 5 6
# 5 6
# 5 6
# 5 6
# 5 6
# 5 6
# 6 5
# 6 5
# 6 5
# 6 5
# 6 5
# 6 5
# 7 4
# 7 4
# 7 4
# 7 4
# 7 4
# 7 4
# 8 3
# 8 3
# 8 3
# 8 3
# 8 3
# 8 3
# 9 2
# 9 2
# 9 2
# 9 2
# 9 2
# 9 2
# 9 2
# 9 2
# 9 2
# 2 15
# 2 15
# 2 15
# 2 15
# 2 15
# 2 15
# 3 14
# 3 14
# 3 14
# 3 14
# 3 14
# 3 14
# 4 13
# 4 13
# 4 13
# 4 13
# 4 13
# 4 13
# 5 12
# 5 12
# 5 12
# 5 12
# 5 12
# 5 12
# 6 11
# 6 11
# 6 11
# 6 11
# 6 11
# 6 11
# 7 10
# 7 10
# 7 10
# 7 10
# 7 10
# 7 10
# 8 9
# 8 9
# 8 9
# 8 9
# 8 9
# 8 9
# 9 8
# 9 8
# 9 8
# 9 8
# 9 8
# 9 8
# 10 7
# 10 7
# 10 7
# 10 7
# 10 7
# 10 7
# 11 6
# 11 6
# 11 6
# 11 6
# 11 6
# 11 6
# 12 5
# 12 5
# 12 5
# 12 5
# 12 5
# 12 5
# 13 4
# 13 4
# 13 4
# 13 4
# 13 4
# 13 4
# 14 3
# 14 3
# 14 3
# 14 3
# 14 3
# 14 3
# 15 2
# 15 2
# 15 2
# 15 2
# 15 2
# 15 2
# 2 21
# 2 21
# 2 21
# 2 21
# 2 21
# 2 21
# 3 20
# 3 20
# 3 20
# 3 20
# 3 20
# 3 20
# 4 19
# 4 19
# ...
